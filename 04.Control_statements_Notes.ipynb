# %% [markdown]
# <a href="https://colab.research.google.com/github/nigowda/Beginner-Python-1/blob/main/04.Control_statements_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Control statements** (2 hours)

# %% [markdown]
# ## **Content**
#
#
# 1. Control statements
#      - Syntax
#      - indentation
#      - if block
#      - if else block
#      - elif block
#
# 2. Advanced usage of Control Statements

# %% [markdown]
# ## **Syntax for conditions in python**

# %% [markdown]
# **Pseudo code**
# ```
# if condition:
#   print(something)
#   a = True
# ```

# %% [markdown]
# ### **If Block**

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# ### **Indentation**

# %% [markdown]
# - Python uses indentation over curly braces
# - Everything with same indent becomes part of one block

# %%
#one indent- 4spaces/2spaces
if 56 > 50:
  print("1")
  print("2") #1 2
# Out:
# 1
# 2

# %%
if 56 > 50:
  print("1")
  print("2")
print("3") # 1 2 3
# Out:
# 1
# 2
# 3

# %%
if 5 > 50:
  print("1")
  print("2")
print("3")
# Out:
# 3

# %% [markdown]
# ### **If else block**

# %% [markdown]
# ```python
# if True:
#   #Run these statements
# else:
#   #Run these statements
# #Run these always
# ```

# %%
a=2
result = a ** 5
if result > 25:
  print("That is massive!")
else:
  print("pretty small!")
print("complete")
# Out:
# That is massive!
# complete

# %%
a = 2
result = a ** 5
if result > 25:
  print("That is massive!")
else:
  print("pretty small!")
print("complete")
# Out:
# That is massive!
# complete

# %% [markdown]
# ### **Flowchart for the problem above**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Question - Check Password**
# * print `"password incorrect"` if **incorrect**.
# * print `"password correct"` if **correct**.

# %%
original_password="password"
password=input("Please enter password:")
if (original_password == password):
  print("password correct")
else:
  print("password incorrect")
# Out:
# Please enter password:adad
# password incorrect

# %%
original_password="password"
password=input("Please enter password:")
if (original_password == password):
  print("password correct")
else:
  print("password incorrect")
# Out:
# Please enter password:password
# password correct

# %% [markdown]
# ## **Question-2 ATM Dispatch**
# * 500 and 200 Rs notes are available
# * Take amount from user, if amount dischargeable, `print("Discharging cash")`
# * Else, `print("Denomination not available")`

# %%
amount = int(input('Enter amount'))
if (amount%500)%200 == 0 :
  print('Discharging cash')
else:
  print('Denomination not available')
# Out:
# Enter amount500
# Discharging cash

# %%
0%200
# Out:
# 0

# %%
amount=int(input())
if amount%500==0 or amount%200==0:
  print("Discharging cash")
else:
  print("Denomination not available")
# Out:
# 1000
# Discharging cash

# %% [markdown]
# *italicized text*## **Greeting in 24hr format**

# %%
time = int(input())
if time > 9 and time <= 12:
  print("Good morning")
else:
  if time > 12 and time <= 17:
    print("Good afternoon")
  else:
    if(time > 17 and time <= 24):
      print("Good night")
    else:
      print("SOJAOO!")
# Out:
# 1
# SOJAOO!

# %%
time = int(input())
if time > 9 and time <= 12:
  print("Good morning")
else:
  if time > 12 and time <= 17:
    print("Good afternoon")
  else:
    if(time > 17 and time <= 24):
      print("Good night")
    else:
      print("SOJAOO!")
# Out:
# 10
# Good morning

# %% [markdown]
# ## **Elif Block**

# %% [markdown]
# **Pseudocode**
# ```
# if condition1:
#   this
# elif condition2:
#   this
# else:
#   this
# ```

# %%
time = int(input())
if time > 9 and time <= 12:
  print("Good morning")
elif time > 12 and time <= 17:
  print("Good afternoon")
elif (time > 17 and time <= 24):
  print("Good night")
else:
  print("SOJAOO!")
# Out:
# 10
# Good morning

# %% [markdown]
# ## **Homework question**
# ```python
# #ATM dispatch
# # there are 500 Rs and 200 Rs notes available
# # Dispatch money such that it uses maximum 500Rs notes
# #print("Discharging cash") if amount dischargeable
# #else print("Denomination not available")

# %% [markdown]
# # **Advanced Questions on Usage of Control Statements**

# %% [markdown]
# ## **Question** - Positive or negative
# * Take an integer input and print if its positive or negative

# %%
number = int(input())
if number >= 0:
  print("number is positive")
else:
  print("number is negative")
# Out:
# 2
# number is positive

# %% [markdown]
# ## **Evaluate expression**
# * Take a non negative single digit number as input.
# * If `num ** 5 % 50 + 20 - 6` > `15` then `print("BLACK")` else `print("BLUE")`.
# ######**NOTE**: reject non single digit number

# %%
# 1
number=int(input())
if number >= 0 and number <= 9:
  if number**5 % 50 + 20 - 6 > 15:
    print("BLACK")
  else:
    print("BLUE")
else:
  print("number not valid!")
# Out:
# 902
# number not valid!

# %%
# 2
number=int(input())
if not number >= 0 and number <= 9:
  print("number not valid!")
else:
  if number**5 % 50 + 20 - 6 > 15:
    print("BLACK")
  else:
    print("BLUE")
# Out:
# 2
# BLACK

# %%
# 3
number=int(input())
if number < 0 and number > 9:
  print("number not valid!")
else:
  if number**5 % 50 + 20 - 6 > 15:
    print("BLACK")
  else:
    print("BLUE")
# Out:
# 1
# BLUE

# %% [markdown]
# ## **Question** - Evaluate String
# * Take a string input and if the entered language is "Python" `print("great choice!")` else `print("Think again?")`

# %%
language=input()
if language=="Python" or language=="python":
  print("great choice!")
else:
  print("Think again?")
# Out:
# Python
# great choice!

# %% [markdown]
# ### **lower()**
# - Converts all characters in the string to lowercase.

# %%
"pyTHON".lower() #python
# Out:
# 'python'

# %% [markdown]
# ## **Question** - Language Choice

# %% [markdown]
# * Take a string input and if the entered language is `"Python"` or `"JAVA"` `print("wow")` else `print("are you living under a rock?")`
# #####**NOTE**: Reject integer inputs

# %%
language=input()

if language=="Python" or language=="JAVA":
    print("wow")
else:
    print("are you living under a rock?")
# Out:
# JAVA
# wow

# %% [markdown]
# ## **Question** - Positive or negative float
# * Take an integer input and print if its positive or negative or float.

# %%
number = float(input())
if number >= 0:
    print("number is positive float")
else:
    print("number is negative float")
# Out:
# 8984
# number is positive float

# %% [markdown]
# ## **Question** - Feedback System
# * Take string feedback from a user.
# * Now if any the feedback is provided, `print("Thank you for providing the feedback")`.
# * If feedback is **"Super"**, **"Great"**, **"Fantastic"**, **"Awesome"**, `print("Thank you so much!")`.

# %%
feedback = input()
if feedback:
    print("Thank you so much!")
if feedback.lower() == "super" or feedback.lower() == "awesome":
    print("Thank You!")

# %%
feedback = input()
if feedback!="":
    print("Thank you so much!")

if feedback.lower() == "super" or feedback.lower() == "awesome":
    print("Thank You!")
# Out:
# awesome
# Thank you so much!
# Thank You!

# %%
if feedback == "":
    print("Please provide feedback next time.")
else:
    if feedback.lower() == "super" or feedback.lower() == "awesome":
        print("Thank You!")
# Out:
# Thank You!

# %% [markdown]
# ## **Question** - FIZZ BUZZ
# * Take an input N. If N is a multiple of 3, print `FIZZ`, else if N is a multiple of 5 print `BUZZ` else if N is a multiple of both 3 and 5, print `FIZZBUZZ`.

# %%
# Wrong order of statements
n = int(input())
if n % 3 == 0:
    print("FIZZ")
elif n % 5 == 0:
    print("BUZZ")
elif n % 3 == 0 and n % 5 == 0:
    print("FIZZBUZZ")
# Out:
# 15
# FIZZ

# %%
# Correct order
n = int(input())
if n % 3 == 0 and n % 5 == 0:
    print("FIZZBUZZ")
elif n % 3 == 0:
    print("FIZZ")
elif n % 5 == 0:
    print("BUZZ") #correct answer
# Out:
# 15
# FIZZBUZZ

# %% [markdown]
# ## **Question** - Stream Selection
# * Take in three inputs from a user which are marks in `english`, `maths` and `science`. Assign streams according to the following criteria
# * If **science > 90** or marks in **all** are greater than 75 -> `Science`
# * If marks in all are greater than 60 or equal and less than 75 -> `Commerce`
# * If marks in all are less than 60 -> `Humanities`

# %%
science = int(input())
english = int(input())
maths = int(input())

if (science > 90) or ((science >= 75) and (english >= 75) and (maths >= 75)):
  print("Science")
elif (60 <= science < 75 and 60 <= english < 75 and 60 <= maths < 75):
  print("Commerce")
elif (science < 60 and english < 60 and maths < 60) :
  print("Humanities")
else:
  print("None of these")
# Out:
# 70
# 20
# 20
# Humanities

# %%
A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
Ask user for their salary and year of service and print the net bonus amount.

# %%
Ask user to enter age, sex ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
if employee is female, then she will work only in urban areas.

if employee is a male and age is in between 20 to 40 then he may work in anywhere

if employee is male and age is in between 40 t0 60 then he will work in urban areas only.

And any other input of age should print "ERROR".
